# %% [markdown]
# <a href="https://colab.research.google.com/github/chayanondevv/2110640-INFO-SECURITY/blob/main/Assignment_security_policy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Scenerio**
# Our university is launching a new,all-in-one online portal. This portal will handle everything from `student registration and grade management to faculty collaboration and research data storage`. The system must protect student privacy, ensure academic integrity,and manage potential conflicts of interest among researchers.

# %% [markdown]
# **Tasks:**
# 1. Define the security policy for this portal.
# 2. Identify subjects and objects
# 3. Choose a primary Access Control
# 4. Model or Security Framework
# 5. Make an Access Control Matrix

# %% [markdown]
# 1. Define the security policy for this portal.
#
#
# > Control access to research data in the university system using both roles and attributes to ensure that each user can manage their own data, and that access by others must be explicitly authorized

# %% [markdown]
# 2. Identify subjects and objects
#
#   **Subjects**
#   *   Admin
#   *   Student
#   *   Professor
#   *   Researcher
#   *   Registrar
#
#   **Objects**
#
#   *   Student registration
#   *   Grade management
#   *   Research data storage
#   *   System Settings

# %% [markdown]
# 3. Choose a primary Access Control
# > Role-Based Access Control

# %% [markdown]
# 4. Model or Security Framework
#   > Multilateral Security

# %% [markdown]
# 5. Make an Access Control Matrix
# ![Screenshot 2568-08-29 at 14.34.07.png](data:image/png;base64,...)
